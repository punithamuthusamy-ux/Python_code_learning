# %% [markdown]
# <a href="https://colab.research.google.com/github/punithamuthusamy-ux/Python_code_learning/blob/main/Python_Assignment_3_While_Loop%2C_For_Loop_and_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Assignment-3: While Loop, For Loop and Function**

# %% [markdown]
# #**While Loop**
#
# **Number Guessing Game**

# %%
# 1. Set Up the Game:
# Generate a random number between 1 and 10

import random
secret_number = random.randint(1, 10)

# 2. Prompt the User:
# Maximum Attempts

attempts = 0

# 3. Implement the Guessing Logic:

print("Welcome to the Number Guessing Game!")
print("I'm thinking of a number between 1 and 10.")

while True:
    try:
        attempts += 1 # Increment attempts before each guess
        guess = int(input("Take a guess: "))

        if guess < secret_number:
            print("Your guess is too low!")
        elif guess > secret_number:
            print("Your guess is too high!")
        else:
            print(f"Congratulations! You guessed the number {secret_number} in {attempts} attempts!")
            break
    except ValueError:
        print("Invalid input. Please enter an integer.")
        continue
# Out:
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 10.

# %% [markdown]
# #**For Loop**
#
# **Multiplication Table Generator**

# %%
# 1. Prompt user for Input. Ask the user to enter a number for which they want to generate a multiplication table.

number = int(input("Enter the number for which you want the multiplication table: "))
# Out:
# Enter the number for which you want the multiplication table: 5

# %%
# 2 & 3: Generate and display the multiplication table
for i in range(1, 11):
    result = number * i
    print(f"{number} xi {i} = {result}")
# Out:
# 5 xi 1 = 5
# 5 xi 2 = 10
# 5 xi 3 = 15
# 5 xi 4 = 20
# 5 xi 5 = 25
# 5 xi 6 = 30
# 5 xi 7 = 35
# 5 xi 8 = 40
# 5 xi 9 = 45
# 5 xi 10 = 50

# %% [markdown]
# #**Function**
#
# **BMI Calculator**

# %%
# 1. Define a function calculate_bmi(weight, height) that returns the BMI.

def calculate_bmi(weight, height):
    return weight / (height ** 2)

# 2. Prompt the user for their weight (in kg) and height (in meters).

weight = float(input("Enter your weight in kilograms: "))
height = float(input("Enter your height in meters: "))

# 3. Use the function to calculate and display the BMI

bmi = calculate_bmi(weight, height)
print("Your BMI is:", bmi)
# Out:
# Enter your weight in kilograms: 89
# Enter your height in meters: 152
# Your BMI is: 0.003852146814404432

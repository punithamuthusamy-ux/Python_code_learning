# %% [markdown]
# <a href="https://colab.research.google.com/github/punithamuthusamy-ux/Python_code_learning/blob/main/Python_Assignment_1_Data_Structures_Strings_%26_Tuples_Str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Assignment 1: Data Structures - Strings & Tuples**

# %% [markdown]
# **1. String Concatenation**

# %%
# 1. String (Welcome Note)

Name = "Hello"
print(Name)
# Out:
# Hello

# %%
# 2. String

Name = " Hellp Punitha"
print(Name)
# Out:
#  Hellp Punitha

# %%
# 3. String

Name = "Hello Punitha"
Greetings = Name + " , " "Welcome to Python Programming"
print(Greetings)
# Out:
# Hello Punitha , Welcome to Python Programming

# %% [markdown]
# **2. String Slicing and Indexing**

# %%
# length of greetings

len(Greetings)
# Out:
# 45

# %%
# a. Print the first character of the string

print(Greetings[1])
# Out:
# e

# %%
# b. Print the last character of the string

print(Greetings[44])
# Out:
# g

# %%
# c. Print the first 5 characters of the string

print(Greetings[:5])
# Out:
# Hello

# %%
# d. Print the last 11 characters of the string

print(Greetings[-11:])
# Out:
# Programming

# %%
# e. Print the string in reverse

print("Reversed Greetings:" , Greetings[::-1])
# Out:
# Reversed Greetings: gnimmargorP nohtyP ot emocleW , ahtinuP olleH

# %%
# f. Use slicing and print the word “Python” from the existing string

print(Greetings[27:33])
# Out:
# Python

# %% [markdown]
# **3. String Methods**

# %%
M = "Python beginner tutorial"

# %%
# a. Convert the sentence to uppercase

print("Upper case:" , M.upper())
# Out:
# Upper case: PYTHON BEGINNER TUTORIAL

# %%
# b. Convert the sentence to lowercase

print("Lower case:" , M.lower())
# Out:
# Lower case: python beginner tutorial

# %%
# c. Use Capitalize and return the sentence to the original input form

print("Capitalized:" , M.capitalize())
# Out:
# Capitalized: Python beginner tutorial

# %%
# d. Count the total number of occurrences of character ‘t’ in the string

count_t = M.count("t")
print("Occurances of T:" , count_t)
# Out:
# Occurances of T: 3

# %%
# e. Replace all occurrences of “Python” with “Machine Learning” in the input string strM = Python beginner tutorial

print("Replace Python - Machine Learning:" , M.replace("Python", "Machine Learning"))
M = M.replace("Python", "Machine Learning")
print(M)
# Out:
# Replace Python - Machine Learning: Machine Learning beginner tutorial
# Machine Learning beginner tutorial

# %% [markdown]
# **Tuples (Creation, Modification and Access)**

# %%
# Tuple

tuple1 = (10, 20, 30)
tuple2 = (40, 50, 60)

print(tuple1)
print(tuple2)
# Out:
# (10, 20, 30)
# (40, 50, 60)

# %%
# a. Concatenate the two tuples and store it in “t_combine”

t_combine = tuple1 + tuple2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
# b. Repeat the elements of “t_combine” 3 times

t_combine = (10, 20, 30, 40, 50, 60)
print("t_combine_repeat:" , t_combine * 3)
# Out:
# t_combine_repeat: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
# c. Access the 3rd element from “t_combine”

t_combine = (10, 20, 30, 40, 50, 60)
print("Third element:" , t_combine[2])
# Out:
# Third element: 30

# %%
# d. Access the first three elements from “t_combine”

t_combine = (10, 20, 30, 40, 50, 60)
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
# e. Access the last three elements from “t_combine”

t_combine = (10, 20, 30, 40, 50, 60)
print(t_combine[3:])
# Out:
# (40, 50, 60)
